# %% [markdown]
# # Prediction via Random Forest Model

# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload

# %%
import pandas as pd
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
from functions import read_merge_prepare_data, train_test_rolling

# %% [markdown]
# ## Prepare Data Input

# %%
 # Setting display options to show all columns without truncation
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
periods = ['Q1', 'Q2', 'Q3', 'A1', 'A2']

# %%
macro_file_path = "data/processed_data/macro_data.csv"
Macro_Data = pd.read_csv(macro_file_path)

# %%
# Create an empty dictionary to store DataFrames
forecast_data = {}

# Read CSV files into DataFrames and store them in the dictionary
for forecast in periods:
    forecast_data[forecast] = read_merge_prepare_data(forecast, Macro_Data)
# Out:
# Q1 Missing Values:
# price              17
# ret                19
# capei           41209
# be              41209
# bm              41209
#                 ...
# mktcap          41209
# ptb             41209
# peg_trailing    41209
# divyield        41209
# ffi49           41209
# Length: 72, dtype: int64
# Q2 Missing Values:
# price              14
# ret                15
# capei           34856
# be              34856
# bm              34856
#                 ...
# mktcap          34856
# ptb             34856
# peg_trailing    34856
# divyield        34856
# ffi49           34856
# Length: 72, dtype: int64
# Q2 Missing Values:
# price              14
# ret                15
# capei           34856
# be              34856
# bm              34856
#                 ...
# mktcap          34856
# ptb             34856
# peg_trailing    34856
# divyield        34856
# ffi49           34856
# Length: 72, dtype: int64
# Q3 Missing Values:
# price              14
# ret                15
# capei           30495
# be              30495
# bm              30495
#                 ...
# mktcap          30495
# ptb             30495
# peg_trailing    30495
# divyield        30495
# ffi49           30495
# Length: 72, dtype: int64
# Q3 Missing Values:
# price              14
# ret                15
# capei           30495
# be              30495
# bm              30495
#                 ...
# mktcap          30495
# ptb             30495
# peg_trailing    30495
# divyield        30495
# ffi49           30495
# Length: 72, dtype: int64
# A1 Missing Values:
# price              19
# ret                21
# capei           39955
# be              39955
# bm              39955
#                 ...
# mktcap          39955
# ptb             39955
# peg_trailing    39955
# divyield        39955
# ffi49           39955
# Length: 72, dtype: int64
# A1 Missing Values:
# price              19
# ret                21
# capei           39955
# be              39955
# bm              39955
#                 ...
# mktcap          39955
# ptb             39955
# peg_trailing    39955
# divyield        39955
# ffi49           39955
# Length: 72, dtype: int64
# A2 Missing Values:
# price              10
# ret                11
# capei           30240
# be              30240
# bm              30240
#                 ...
# mktcap          30240
# ptb             30240
# peg_trailing    30240
# divyield        30240
# ffi49           30240
# Length: 72, dtype: int64
# A2 Missing Values:
# price              10
# ret                11
# capei           30240
# be              30240
# bm              30240
#                 ...
# mktcap          30240
# ptb             30240
# peg_trailing    30240
# divyield        30240
# ffi49           30240
# Length: 72, dtype: int64

# %% [markdown]
# # Rolling window Random Forest

# %%
results_rolling = {}

# note: run 18 min for Q1 with 1% sample
for forecast, df in forecast_data.items():
    print(forecast)
    results_rolling[forecast] = train_test_rolling(forecast, df)
    # Save the results to CSV
    results_rolling[forecast].to_csv(f"results/{forecast}_rf.csv", index=False)
    print(f"Results for {forecast} saved to results/{forecast}_rf.csv")
# Out:
# Q1
# Length total df: 887766
#   0%|          | 0/408 [00:00<?, ?it/s]/Users/yandong/Documents/GitHub/Man-vs-machine/functions.py:215: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   y_hat_test_RF = pd.concat([y_hat_test_RF, pd.Series(forest_model_rf.predict(X_test))])
# /Users/yandong/Documents/GitHub/Man-vs-machine/functions.py:272: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   y_hat_test_LR = pd.concat([y_hat_test_LR, y_hat_LR_temp ])
#   0%|          | 1/408 [00:01<07:12,  1.06s/it]/Users/yandong/Documents/GitHub/Man-vs-machine/functions.py:215: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   y_hat_test_RF = pd.concat([y_hat_test_RF, pd.Series(forest_model_rf.predict(X_test))])
# /Users/yandong/Documents/GitHub/Man-vs-machine/functions.py:272: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   y_hat_test_LR = pd.concat([y_hat_test_LR, y_hat_LR_temp ])
# 100%|██████████| 408/408 [16:42<00:00,  2.46s/it]
# Results for Q1 saved to results/Q1_rf.csv
# Q2
# Length total df: 813542
# Length total df: 813542
#   0%|          | 0/408 [00:00<?, ?it/s]/Users/yandong/Documents/GitHub/Man-vs-machine/functions.py:215: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   y_hat_test_RF = pd.concat([y_hat_test_RF, pd.Series(forest_model_rf.predict(X_test))])
# /Users/yandong/Documents/GitHub/Man-vs-machine/functions.py:272: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   y_hat_test_LR = pd.concat([y_hat_test_LR, y_hat_LR_temp ])
#   0%|          | 1/408 [00:00<06:27,  1.05it/s]/Users/yandong/Documents/GitHub/Man-vs-machine/functions.py:215: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   y_hat_test_RF = pd.concat([y_hat_test_RF, pd.Series(forest_model_rf.predict(X_test))])
# /Users/yandong/Documents/GitHub/Man-vs-machine/functions.py:272: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   y_hat_test_LR = pd.concat([y_hat_test_LR, y_hat_LR_temp ])
# 100%|██████████| 408/408 [15:34<00:00,  2.29s/it]
# Results for Q2 saved to results/Q2_rf.csv
# Q3
# Length total df: 749593
# Length total df: 749593
#   0%|          | 0/408 [00:00<?, ?it/s]/Users/yandong/Documents/GitHub/Man-vs-machine/functions.py:215: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   y_hat_test_RF = pd.concat([y_hat_test_RF, pd.Series(forest_model_rf.predict(X_test))])
# /Users/yandong/Documents/GitHub/Man-vs-machine/functions.py:272: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   y_hat_test_LR = pd.concat([y_hat_test_LR, y_hat_LR_temp ])
#   0%|          | 1/408 [00:00<06:26,  1.05it/s]/Users/yandong/Documents/GitHub/Man-vs-machine/functions.py:215: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   y_hat_test_RF = pd.concat([y_hat_test_RF, pd.Series(forest_model_rf.predict(X_test))])
# /Users/yandong/Documents/GitHub/Man-vs-machine/functions.py:272: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   y_hat_test_LR = pd.concat([y_hat_test_LR, y_hat_LR_temp ])
# 100%|██████████| 408/408 [14:52<00:00,  2.19s/it]
# Results for Q3 saved to results/Q3_rf.csv
# A1
# Length total df: 873169
# Length total df: 873169
#   0%|          | 0/408 [00:00<?, ?it/s]/Users/yandong/Documents/GitHub/Man-vs-machine/functions.py:215: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   y_hat_test_RF = pd.concat([y_hat_test_RF, pd.Series(forest_model_rf.predict(X_test))])
# /Users/yandong/Documents/GitHub/Man-vs-machine/functions.py:272: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   y_hat_test_LR = pd.concat([y_hat_test_LR, y_hat_LR_temp ])
#   0%|          | 1/408 [00:00<06:07,  1.11it/s]/Users/yandong/Documents/GitHub/Man-vs-machine/functions.py:215: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   y_hat_test_RF = pd.concat([y_hat_test_RF, pd.Series(forest_model_rf.predict(X_test))])
# /Users/yandong/Documents/GitHub/Man-vs-machine/functions.py:272: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   y_hat_test_LR = pd.concat([y_hat_test_LR, y_hat_LR_temp ])
# 100%|██████████| 408/408 [16:21<00:00,  2.41s/it]
# Results for A1 saved to results/A1_rf.csv
# A2
# Length total df: 748271
# Length total df: 748271
#   0%|          | 0/396 [00:00<?, ?it/s]/Users/yandong/Documents/GitHub/Man-vs-machine/functions.py:215: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   y_hat_test_RF = pd.concat([y_hat_test_RF, pd.Series(forest_model_rf.predict(X_test))])
# /Users/yandong/Documents/GitHub/Man-vs-machine/functions.py:272: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   y_hat_test_LR = pd.concat([y_hat_test_LR, y_hat_LR_temp ])
#   0%|          | 1/396 [00:01<07:10,  1.09s/it]/Users/yandong/Documents/GitHub/Man-vs-machine/functions.py:215: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   y_hat_test_RF = pd.concat([y_hat_test_RF, pd.Series(forest_model_rf.predict(X_test))])
# /Users/yandong/Documents/GitHub/Man-vs-machine/functions.py:272: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   y_hat_test_LR = pd.concat([y_hat_test_LR, y_hat_LR_temp ])
# 100%|██████████| 396/396 [27:12<00:00,  4.12s/it]
# Results for A2 saved to results/A2_rf.csv

# %% [markdown]
# ## Visualize Results

# %%
# reread file saved from previous step
results_rolling = {}
for period in periods:
    results_rolling[period] = pd.read_csv(f"results/{period}_rf.csv")

# %%
for period in periods:
    f = plt.figure()
    fig, ax = plt.subplots(1,2, figsize=(12, 4))
    ax[0].plot(results_rolling[period].adj_actual, results_rolling[period].predicted_adj_actual, '.', color='blue')
    ax[0].plot([-10, 10], [-10, 10], 'r-')
    ax[0].set_xlabel('Actual Value')
    ax[0].set_ylabel('Model Prediction')
   
    print(f' bias for {period}  = {results_rolling[period].bias_AF_ML.mean()}')

    # plot forecast and exact 
    ax[1].plot(results_rolling[period].adj_actual, results_rolling[period].meanest, '.', color='blue')
    ax[1].plot([-10,10], [-10,10], 'r-')
    ax[1].set_xlabel('Actual Value')
    ax[1].set_ylabel('Analyst Forecast')
    ax[1].set_ylim(-10,10)
    f.savefig(f'images/{period}_RF_forecast_and_analyst_vs_actual.pdf', dpi=100, format='pdf')
# Out:
#  bias for Q1  = 0.005354811547214987
#  bias for Q2  = 0.006341525963454618
#  bias for Q3  = 0.0067454044772946396
#  bias for A1  = 0.016461588052632193
#  bias for A2  = 0.02305669224357398
#  bias for Q2  = 0.006341525963454618
#  bias for Q3  = 0.0067454044772946396
#  bias for A1  = 0.016461588052632193
#  bias for A2  = 0.02305669224357398

# %%
for period, df in results_rolling.items():
    fig, ax = plt.subplots(1,1, figsize=(10, 4))
    plt.scatter(range(len(df)),df.adj_actual, s=1)
    plt.xlabel('Actual Value')
    plt.show()

# %%
for period, df in results_rolling.items():
    print(f' {period} r2_score RF is {r2_score(df.adj_actual, df.predicted_adj_actual)}')
    print(f' {period} r2_score LR is {r2_score(df.adj_actual, df.predicted_adj_actual_LR)}')
    print(f' {period} r2_score analyst  is {r2_score(df.adj_actual, df.meanest)}')
# Out:
#  Q1 r2_score RF is 0.6954361019140218
#  Q1 r2_score LR is -6.34547727023895e+17
#  Q1 r2_score analyst  is 0.7505454641607744
#  Q2 r2_score RF is 0.6400456355970043
#  Q2 r2_score LR is -1.237308109406855e+18
#  Q2 r2_score analyst  is 0.6778235931242504
#  Q3 r2_score RF is 0.5913308143471545
#  Q3 r2_score LR is -2.7262785767916923e+18
#  Q3 r2_score analyst  is 0.6083194088011075
#  A1 r2_score RF is 0.837107896053017
#  A1 r2_score LR is -3.1396634254682117e+18
#  A1 r2_score analyst  is 0.8404098250572669
#  A2 r2_score RF is 0.6570664885985414
#  A2 r2_score LR is -3.5166122585644073e+19
#  A2 r2_score analyst  is 0.5654204038764042

# %% [markdown]
# We see our model has better R squared in all the period dataframe.
#
#
# The plot also make us udnerstand why the ml preidctions are bounded: as we train on 1% on the train df evrytime, as we see, the majority of oint on whixh we train will be taken froma  subrnage of the all observation range.
