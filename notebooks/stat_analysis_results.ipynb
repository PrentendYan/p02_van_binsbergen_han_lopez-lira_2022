# %% [markdown]
# # STATISTICAL ANALYSIS
# ## Regression to explain bias

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
periods = ['Q1', 'Q2', 'Q3', 'A1', 'A2']

# %%
data = {}
for period in periods:
    data[period] = pd.read_csv(f"results/{period}_rf.csv")

# %% [markdown]
# **Hypothesis Testing:**
#
# - After fitting the model, the coefficients and p-values for post_regulation (gamma) and N_analyst (lambda) are extracted.
# - The script checks if these coefficients are negative and if their p-values are less than 0.05 (indicating statistical significance).
# - It then prints whether each coefficient is both negative and statistically significant.

# %% [markdown]
# ## Regression for regulation of nov 2000

# %%
results = {}
for period in periods:
    data[period].rename(columns={'numest':'N_analyst'}, inplace=True)
    data[period]['post_regulation'] = np.where(data[period].Date> '2000-10', 1, 0)

    # alpha_i is the average bias_AF_ML for each permno.
    data[period]['alpha_i'] = data[period].groupby('permno')['bias_AF_ML'].transform('mean')
    
    # beta_t is the average bias_AF_ML for each Date.
    data[period]['beta_t'] = data[period].groupby('Date')['bias_AF_ML'].transform('mean')

    # Define the independent variables
    X = data[period][['alpha_i', 'beta_t', 'post_regulation']]
    # X = sm.add_constant(X)  # No: fixed aprte conisdered in alpha and beta 
    
    # Define the dependent variable
    y = data[period]['bias_AF_ML']
    
    # Fit the regression model
    model = sm.OLS(y, X).fit()
    
    # Save the results
    results[period] = model.summary()
    
    # Print summary for each period
    print(f"Summary for {period}:")
    print(model.summary())

    # Hypothesis tests for gamma and lambda
    gamma_pvalue = model.pvalues['post_regulation']
    
    gamma_coefficient = model.params['post_regulation']
    
    
    print(f"\nHypothesis tests for {period}:")
    print(f"gamma (post_regulation) coefficient: {gamma_coefficient}, p-value: {gamma_pvalue}")
    
    gamma_significant = gamma_pvalue < 0.05
    
    print(f"Is gamma significant? {'Yes' if gamma_significant  else 'No'}")
# Out:
# Summary for Q1:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             bias_AF_ML   R-squared (uncentered):                   0.260
# Model:                            OLS   Adj. R-squared (uncentered):              0.260
# Method:                 Least Squares   F-statistic:                          1.032e+05
# Date:                Tue, 17 Feb 2026   Prob (F-statistic):                        0.00
# Time:                        12:17:24   Log-Likelihood:                      1.0217e+06
# No. Observations:              881903   AIC:                                 -2.043e+06
# Df Residuals:                  881900   BIC:                                 -2.043e+06
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# alpha_i             0.9884      0.002    536.248      0.000       0.985       0.992
# beta_t              0.7882      0.007    108.928      0.000       0.774       0.802
# post_regulation    -0.0038      0.000    -34.839      0.000      -0.004      -0.004
# ==============================================================================
# Omnibus:                  2964322.518   Durbin-Watson:                   1.993
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):   37504440698313.352
# Skew:                          58.549   Prob(JB):                         0.00
# Kurtosis:                   31950.262   Cond. No.                         70.6
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Hypothesis tests for Q1:
# gamma (post_regulation) coefficient: -0.003834357622219452, p-value: 9.378943120987646e-266
# Is gamma significant? Yes
# Summary for Q2:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             bias_AF_ML   R-squared (uncentered):                   0.257
# Model:                            OLS   Adj. R-squared (uncentered):              0.257
# Method:                 Least Squares   F-statistic:                          9.340e+04
# Date:                Tue, 17 Feb 2026   Prob (F-statistic):                        0.00
# Time:                        12:17:25   Log-Likelihood:                      8.9861e+05
# No. Observations:              808189   AIC:                                 -1.797e+06
# Df Residuals:                  808186   BIC:                                 -1.797e+06
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# alpha_i             0.9890      0.002    510.618      0.000       0.985       0.993
# beta_t              0.7860      0.008     98.850      0.000       0.770       0.802
# post_regulation    -0.0046      0.000    -37.779      0.000      -0.005      -0.004
# ===============================================================================
# Omnibus:                  3529716.496   Durbin-Watson:                    2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):   124820078340330.203
# Skew:                        -134.797   Prob(JB):                          0.00
# Kurtosis:                   60884.749   Cond. No.                          72.4
# ===============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Hypothesis tests for Q2:
# gamma (post_regulation) coefficient: -0.004610074801444834, p-value: 0.0
# Is gamma significant? Yes
# Summary for Q3:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             bias_AF_ML   R-squared (uncentered):                   0.192
# Model:                            OLS   Adj. R-squared (uncentered):              0.192
# Method:                 Least Squares   F-statistic:                          5.904e+04
# Date:                Tue, 17 Feb 2026   Prob (F-statistic):                        0.00
# Time:                        12:17:25   Log-Likelihood:                      8.2991e+05
# No. Observations:              744857   AIC:                                 -1.660e+06
# Df Residuals:                  744854   BIC:                                 -1.660e+06
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# alpha_i             0.9841      0.002    399.714      0.000       0.979       0.989
# beta_t              0.7759      0.009     90.008      0.000       0.759       0.793
# post_regulation    -0.0048      0.000    -37.806      0.000      -0.005      -0.005
# ===============================================================================
# Omnibus:                  3640900.765   Durbin-Watson:                    1.994
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):   268424741329955.844
# Skew:                        -198.551   Prob(JB):                          0.00
# Kurtosis:                   93001.615   Cond. No.                          76.7
# ===============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Hypothesis tests for Q3:
# gamma (post_regulation) coefficient: -0.004839133453278922, p-value: 0.0
# Is gamma significant? Yes
# Summary for A1:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             bias_AF_ML   R-squared (uncentered):                   0.299
# Model:                            OLS   Adj. R-squared (uncentered):              0.299
# Method:                 Least Squares   F-statistic:                          1.240e+05
# Date:                Tue, 17 Feb 2026   Prob (F-statistic):                        0.00
# Time:                        12:17:25   Log-Likelihood:                      7.7552e+05
# No. Observations:              871504   AIC:                                 -1.551e+06
# Df Residuals:                  871501   BIC:                                 -1.551e+06
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# alpha_i             0.9644      0.002    559.021      0.000       0.961       0.968
# beta_t              0.6176      0.005    133.634      0.000       0.609       0.627
# post_regulation    -0.0080      0.000    -51.413      0.000      -0.008      -0.008
# ==============================================================================
# Omnibus:                  2374936.247   Durbin-Watson:                   1.983
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):    5661328826731.899
# Skew:                          32.204   Prob(JB):                         0.00
# Kurtosis:                   12489.029   Cond. No.                         33.5
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Hypothesis tests for A1:
# gamma (post_regulation) coefficient: -0.007961401306105355, p-value: 0.0
# Is gamma significant? Yes
# Summary for A2:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             bias_AF_ML   R-squared (uncentered):                   0.493
# Model:                            OLS   Adj. R-squared (uncentered):              0.493
# Method:                 Least Squares   F-statistic:                          2.402e+05
# Date:                Tue, 17 Feb 2026   Prob (F-statistic):                        0.00
# Time:                        12:17:25   Log-Likelihood:                      1.1482e+06
# No. Observations:              739930   AIC:                                 -2.296e+06
# Df Residuals:                  739927   BIC:                                 -2.296e+06
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# alpha_i             0.9228      0.001    692.624      0.000       0.920       0.925
# beta_t              0.5175      0.003    200.197      0.000       0.512       0.523
# post_regulation    -0.0085   9.32e-05    -91.776      0.000      -0.009      -0.008
# ==============================================================================
# Omnibus:                  1146040.723   Durbin-Watson:                   1.916
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):      25084059783.663
# Skew:                           8.495   Prob(JB):                         0.00
# Kurtosis:                     904.846   Cond. No.                         34.6
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Hypothesis tests for A2:
# gamma (post_regulation) coefficient: -0.008549821985729114, p-value: 0.0
# Is gamma significant? Yes

# %% [markdown]
# ## Regression for regulation of nov 2000 and N analyst

# %%
results = {}
for period in periods:
    data[period].rename(columns={'numest':'N_analyst'}, inplace=True)
    data[period]['post_regulation'] = np.where(data[period].Date> '2000-10', 1,0 )
    data[period]['alpha_i'] = data[period].groupby('permno')['bias_AF_ML'].transform('mean')
    data[period]['beta_t'] = data[period].groupby('Date')['bias_AF_ML'].transform('mean')

    # Define the independent variables
    X = data[period][['alpha_i', 'beta_t', 'N_analyst', 'post_regulation']]
    
    # Define the dependent variable
    y = data[period]['bias_AF_ML']
    
    # Fit the regression model
    model = sm.OLS(y, X).fit()
    
    # Save the results
    results[period] = model.summary()
    
    # Print summary for each period
    print(f"Summary for {period}:")
    print(model.summary())

    # Hypothesis tests for gamma and lambda
    gamma_pvalue = model.pvalues['post_regulation']
    lambda_pvalue = model.pvalues['N_analyst']
    
    gamma_coefficient = model.params['post_regulation']
    lambda_coefficient = model.params['N_analyst']
    
    print(f"\nHypothesis tests for {period}:")
    print(f"gamma (post_regulation) coefficient: {gamma_coefficient}, p-value: {gamma_pvalue}")
    print(f"lambda (N_analyst) coefficient: {lambda_coefficient}, p-value: {lambda_pvalue}")
    
    gamma_significant = gamma_pvalue < 0.05
    lambda_significant = lambda_pvalue < 0.05
    
    print(f"Is gamma significant? {'Yes' if gamma_significant  else 'No'}")
    print(f"Is lambda significant? {'Yes' if lambda_significant else 'No'}\n")
# Out:
# Summary for Q1:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             bias_AF_ML   R-squared (uncentered):                   0.260
# Model:                            OLS   Adj. R-squared (uncentered):              0.260
# Method:                 Least Squares   F-statistic:                          7.755e+04
# Date:                Tue, 17 Feb 2026   Prob (F-statistic):                        0.00
# Time:                        12:17:25   Log-Likelihood:                      1.0219e+06
# No. Observations:              881903   AIC:                                 -2.044e+06
# Df Residuals:                  881899   BIC:                                 -2.044e+06
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# alpha_i             0.9872      0.002    535.544      0.000       0.984       0.991
# beta_t              0.8021      0.007    110.454      0.000       0.788       0.816
# N_analyst          -0.0003   1.25e-05    -21.998      0.000      -0.000      -0.000
# post_regulation    -0.0018      0.000    -12.192      0.000      -0.002      -0.001
# ==============================================================================
# Omnibus:                  2963292.519   Durbin-Watson:                   1.995
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):   37541271965250.742
# Skew:                          58.487   Prob(JB):                         0.00
# Kurtosis:                   31965.945   Cond. No.                         804.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Hypothesis tests for Q1:
# gamma (post_regulation) coefficient: -0.0017649051583233382, p-value: 3.4650504213674816e-34
# lambda (N_analyst) coefficient: -0.0002751274240036686, p-value: 3.232800303474169e-107
# Is gamma significant? Yes
# Is lambda significant? Yes
#
# Summary for Q2:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             bias_AF_ML   R-squared (uncentered):                   0.258
# Model:                            OLS   Adj. R-squared (uncentered):              0.258
# Method:                 Least Squares   F-statistic:                          7.016e+04
# Date:                Tue, 17 Feb 2026   Prob (F-statistic):                        0.00
# Time:                        12:17:25   Log-Likelihood:                      8.9877e+05
# No. Observations:              808189   AIC:                                 -1.798e+06
# Df Residuals:                  808185   BIC:                                 -1.797e+06
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# alpha_i             0.9881      0.002    510.089      0.000       0.984       0.992
# beta_t              0.7947      0.008     99.783      0.000       0.779       0.810
# N_analyst          -0.0003   1.55e-05    -18.129      0.000      -0.000      -0.000
# post_regulation    -0.0027      0.000    -16.568      0.000      -0.003      -0.002
# ===============================================================================
# Omnibus:                  3531054.288   Durbin-Watson:                    2.003
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):   125075578212953.656
# Skew:                        -134.969   Prob(JB):                          0.00
# Kurtosis:                   60947.028   Cond. No.                          727.
# ===============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Hypothesis tests for Q2:
# gamma (post_regulation) coefficient: -0.002681753703530001, p-value: 1.2094809206700398e-61
# lambda (N_analyst) coefficient: -0.0002811687740290612, p-value: 1.9542220105074774e-73
# Is gamma significant? Yes
# Is lambda significant? Yes
#
# Summary for Q3:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             bias_AF_ML   R-squared (uncentered):                   0.192
# Model:                            OLS   Adj. R-squared (uncentered):              0.192
# Method:                 Least Squares   F-statistic:                          4.435e+04
# Date:                Tue, 17 Feb 2026   Prob (F-statistic):                        0.00
# Time:                        12:17:26   Log-Likelihood:                      8.3003e+05
# No. Observations:              744857   AIC:                                 -1.660e+06
# Df Residuals:                  744853   BIC:                                 -1.660e+06
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# alpha_i             0.9830      0.002    399.134      0.000       0.978       0.988
# beta_t              0.7845      0.009     90.831      0.000       0.768       0.801
# N_analyst          -0.0003   1.74e-05    -15.322      0.000      -0.000      -0.000
# post_regulation    -0.0032      0.000    -19.149      0.000      -0.004      -0.003
# ===============================================================================
# Omnibus:                  3642235.968   Durbin-Watson:                    1.994
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):   269053097446462.906
# Skew:                        -198.808   Prob(JB):                          0.00
# Kurtosis:                   93110.402   Cond. No.                          701.
# ===============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Hypothesis tests for Q3:
# gamma (post_regulation) coefficient: -0.003196705941375732, p-value: 1.0413350917472113e-81
# lambda (N_analyst) coefficient: -0.0002662090725800612, p-value: 5.5919539112202875e-53
# Is gamma significant? Yes
# Is lambda significant? Yes
#
# Summary for A1:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             bias_AF_ML   R-squared (uncentered):                   0.301
# Model:                            OLS   Adj. R-squared (uncentered):              0.301
# Method:                 Least Squares   F-statistic:                          9.396e+04
# Date:                Tue, 17 Feb 2026   Prob (F-statistic):                        0.00
# Time:                        12:17:26   Log-Likelihood:                      7.7691e+05
# No. Observations:              871504   AIC:                                 -1.554e+06
# Df Residuals:                  871500   BIC:                                 -1.554e+06
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# alpha_i             0.9601      0.002    556.804      0.000       0.957       0.963
# beta_t              0.6816      0.005    142.869      0.000       0.672       0.691
# N_analyst          -0.0007   1.31e-05    -52.817      0.000      -0.001      -0.001
# post_regulation    -0.0032      0.000    -18.201      0.000      -0.004      -0.003
# ==============================================================================
# Omnibus:                  2373591.402   Durbin-Watson:                   1.990
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):    5710472110205.711
# Skew:                          32.150   Prob(JB):                         0.00
# Kurtosis:                   12543.107   Cond. No.                         472.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Hypothesis tests for A1:
# gamma (post_regulation) coefficient: -0.0032489808622019178, p-value: 5.20586735248587e-74
# lambda (N_analyst) coefficient: -0.0006897159333218458, p-value: 0.0
# Is gamma significant? Yes
# Is lambda significant? Yes
#
# Summary for A2:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             bias_AF_ML   R-squared (uncentered):                   0.500
# Model:                            OLS   Adj. R-squared (uncentered):              0.500
# Method:                 Least Squares   F-statistic:                          1.847e+05
# Date:                Tue, 17 Feb 2026   Prob (F-statistic):                        0.00
# Time:                        12:17:26   Log-Likelihood:                      1.1528e+06
# No. Observations:              739930   AIC:                                 -2.306e+06
# Df Residuals:                  739926   BIC:                                 -2.306e+06
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# alpha_i             0.9116      0.001    685.819      0.000       0.909       0.914
# beta_t              0.5974      0.003    221.309      0.000       0.592       0.603
# N_analyst          -0.0008    7.9e-06    -96.340      0.000      -0.001      -0.001
# post_regulation    -0.0037      0.000    -35.002      0.000      -0.004      -0.003
# ==============================================================================
# Omnibus:                  1135711.104   Durbin-Watson:                   1.947
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):      25881218940.561
# Skew:                           8.311   Prob(JB):                         0.00
# Kurtosis:                     919.075   Cond. No.                         474.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Hypothesis tests for A2:
# gamma (post_regulation) coefficient: -0.0036902797660362387, p-value: 3.478981189966186e-268
# lambda (N_analyst) coefficient: -0.0007606627324212471, p-value: 0.0
# Is gamma significant? Yes
# Is lambda significant? Yes
